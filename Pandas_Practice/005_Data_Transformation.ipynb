# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data_csv.csv')

# %%
df
# Out:
#                Actor              Film   Year     Genre  \
# 0     Hrithik Roshan             Dangal  2007     Drama
# 1         Aamir Khan             Barfi!  2018    Action
# 2     Hrithik Roshan             Dangal  2008  Thriller
# 3   Amitabh Bachchan  Bajrangi Bhaijaan  2021    Comedy
# 4        Salman Khan             Kesari  2015  Thriller
# 5         Aamir Khan          Gully Boy  2023   Romance
# 6         Aamir Khan               Piku  2010   Romance
# 7      Rajkummar Rao             Barfi!  2015   Romance
# 8     Shah Rukh Khan              Stree  2000    Biopic
# 9       Akshay Kumar          Gully Boy  2021    Biopic
# 10     Ranbir Kapoor             Dangal  2022    Action
# 11     Ranbir Kapoor               Piku  2010     Drama
#
#     Box Office (INR Crore)  IMDb
# 0                   445.18   8.4
# 1                   255.80   6.4
# 2                   147.77   5.1
# 3                   163.40   5.1
# 4                    65.74   5.8
# ...

# %%
# Sorting the values - the rows labels will not be in order now
df.sort_values('Year')
# Out:
#                Actor              Film   Year     Genre  \
# 8     Shah Rukh Khan              Stree  2000    Biopic
# 0     Hrithik Roshan             Dangal  2007     Drama
# 2     Hrithik Roshan             Dangal  2008  Thriller
# 6         Aamir Khan               Piku  2010   Romance
# 11     Ranbir Kapoor               Piku  2010     Drama
# 4        Salman Khan             Kesari  2015  Thriller
# 7      Rajkummar Rao             Barfi!  2015   Romance
# 1         Aamir Khan             Barfi!  2018    Action
# 9       Akshay Kumar          Gully Boy  2021    Biopic
# 3   Amitabh Bachchan  Bajrangi Bhaijaan  2021    Comedy
# 10     Ranbir Kapoor             Dangal  2022    Action
# 5         Aamir Khan          Gully Boy  2023   Romance
#
#     Box Office (INR Crore)  IMDb
# 8                   176.25   8.2
# 0                   445.18   8.4
# 2                   147.77   5.1
# 6                   311.84   6.2
# 11                  372.00   5.2
# ...

# %%
df.sort_values("Year",ascending=False)
# Out:
#                Actor              Film   Year     Genre  \
# 5         Aamir Khan          Gully Boy  2023   Romance
# 10     Ranbir Kapoor             Dangal  2022    Action
# 3   Amitabh Bachchan  Bajrangi Bhaijaan  2021    Comedy
# 9       Akshay Kumar          Gully Boy  2021    Biopic
# 1         Aamir Khan             Barfi!  2018    Action
# 4        Salman Khan             Kesari  2015  Thriller
# 7      Rajkummar Rao             Barfi!  2015   Romance
# 6         Aamir Khan               Piku  2010   Romance
# 11     Ranbir Kapoor               Piku  2010     Drama
# 2     Hrithik Roshan             Dangal  2008  Thriller
# 0     Hrithik Roshan             Dangal  2007     Drama
# 8     Shah Rukh Khan              Stree  2000    Biopic
#
#     Box Office (INR Crore)  IMDb
# 5                   413.47   8.0
# 10                  405.97   8.3
# 3                   163.40   5.1
# 9                    94.01   8.6
# 1                   255.80   6.4
# ...

# %%
# Sorting on the basis of two columns - if two entries have same year, then on which parameters those row will be sorted
# Use the .copy method since pandas does not guarantees whether a view or a copy will be returned
df2 = df.sort_values(['Year','IMDb']).copy()

# %%
df2
# Out:
#                Actor              Film   Year     Genre  \
# 8     Shah Rukh Khan              Stree  2000    Biopic
# 0     Hrithik Roshan             Dangal  2007     Drama
# 2     Hrithik Roshan             Dangal  2008  Thriller
# 11     Ranbir Kapoor               Piku  2010     Drama
# 6         Aamir Khan               Piku  2010   Romance
# 4        Salman Khan             Kesari  2015  Thriller
# 7      Rajkummar Rao             Barfi!  2015   Romance
# 1         Aamir Khan             Barfi!  2018    Action
# 3   Amitabh Bachchan  Bajrangi Bhaijaan  2021    Comedy
# 9       Akshay Kumar          Gully Boy  2021    Biopic
# 10     Ranbir Kapoor             Dangal  2022    Action
# 5         Aamir Khan          Gully Boy  2023   Romance
#
#     Box Office (INR Crore)  IMDb
# 8                   176.25   8.2
# 0                   445.18   8.4
# 2                   147.77   5.1
# 11                  372.00   5.2
# 6                   311.84   6.2
# ...

# %%
# We want the indices of df2 to start from 0, not mixed up
# df2.reset_index(drop=True, inplace=True)
# df2
df2
# Out:
#                Actor              Film   Year     Genre  \
# 8     Shah Rukh Khan              Stree  2000    Biopic
# 0     Hrithik Roshan             Dangal  2007     Drama
# 2     Hrithik Roshan             Dangal  2008  Thriller
# 11     Ranbir Kapoor               Piku  2010     Drama
# 6         Aamir Khan               Piku  2010   Romance
# 4        Salman Khan             Kesari  2015  Thriller
# 7      Rajkummar Rao             Barfi!  2015   Romance
# 1         Aamir Khan             Barfi!  2018    Action
# 3   Amitabh Bachchan  Bajrangi Bhaijaan  2021    Comedy
# 9       Akshay Kumar          Gully Boy  2021    Biopic
# 10     Ranbir Kapoor             Dangal  2022    Action
# 5         Aamir Khan          Gully Boy  2023   Romance
#
#     Box Office (INR Crore)  IMDb
# 8                   176.25   8.2
# 0                   445.18   8.4
# 2                   147.77   5.1
# 11                  372.00   5.2
# 6                   311.84   6.2
# ...

# %%
# Sort the rows on the basis of index
df2.sort_index()
# Out:
#                Actor              Film   Year     Genre  \
# 0     Hrithik Roshan             Dangal  2007     Drama
# 1         Aamir Khan             Barfi!  2018    Action
# 2     Hrithik Roshan             Dangal  2008  Thriller
# 3   Amitabh Bachchan  Bajrangi Bhaijaan  2021    Comedy
# 4        Salman Khan             Kesari  2015  Thriller
# 5         Aamir Khan          Gully Boy  2023   Romance
# 6         Aamir Khan               Piku  2010   Romance
# 7      Rajkummar Rao             Barfi!  2015   Romance
# 8     Shah Rukh Khan              Stree  2000    Biopic
# 9       Akshay Kumar          Gully Boy  2021    Biopic
# 10     Ranbir Kapoor             Dangal  2022    Action
# 11     Ranbir Kapoor               Piku  2010     Drama
#
#     Box Office (INR Crore)  IMDb  Rank
# 0                   445.18   8.4  11.0
# 1                   255.80   6.4   6.0
# 2                   147.77   5.1   1.5
# 3                   163.40   5.1   1.5
# ...

# %%
# By default what will happen in this case is that the row having the highest value of IMDb will be getting the highest rank
# to do the opposite of this behaviour = ascending = False
# method - dense - integer ranks
df2['Rank'] = df2['IMDb'].rank(ascending=False, method="dense")
df2
# Out:
#                Actor              Film   Year     Genre  \
# 8     Shah Rukh Khan              Stree  2000    Biopic
# 0     Hrithik Roshan             Dangal  2007     Drama
# 2     Hrithik Roshan             Dangal  2008  Thriller
# 11     Ranbir Kapoor               Piku  2010     Drama
# 6         Aamir Khan               Piku  2010   Romance
# 4        Salman Khan             Kesari  2015  Thriller
# 7      Rajkummar Rao             Barfi!  2015   Romance
# 1         Aamir Khan             Barfi!  2018    Action
# 3   Amitabh Bachchan  Bajrangi Bhaijaan  2021    Comedy
# 9       Akshay Kumar          Gully Boy  2021    Biopic
# 10     Ranbir Kapoor             Dangal  2022    Action
# 5         Aamir Khan          Gully Boy  2023   Romance
#
#     Box Office (INR Crore)  IMDb  Rank
# 8                   176.25   8.2   4.0
# 0                   445.18   8.4   2.0
# 2                   147.77   5.1  11.0
# 11                  372.00   5.2  10.0
# ...

# %%
# Changing the order of columns
df2 = df2[['Film ','Actor','Year','Genre','IMDb','Box Office (INR Crore)']]
df2
# Out:
#                 Film              Actor  Year     Genre  IMDb  \
# 8               Stree    Shah Rukh Khan  2000    Biopic   8.2
# 0              Dangal    Hrithik Roshan  2007     Drama   8.4
# 2              Dangal    Hrithik Roshan  2008  Thriller   5.1
# 11               Piku     Ranbir Kapoor  2010     Drama   5.2
# 6                Piku        Aamir Khan  2010   Romance   6.2
# 4              Kesari       Salman Khan  2015  Thriller   5.8
# 7              Barfi!     Rajkummar Rao  2015   Romance   7.5
# 1              Barfi!        Aamir Khan  2018    Action   6.4
# 3   Bajrangi Bhaijaan  Amitabh Bachchan  2021    Comedy   5.1
# 9           Gully Boy      Akshay Kumar  2021    Biopic   8.6
# 10             Dangal     Ranbir Kapoor  2022    Action   8.3
# 5           Gully Boy        Aamir Khan  2023   Romance   8.0
#
#     Box Office (INR Crore)
# 8                   176.25
# 0                   445.18
# 2                   147.77
# 11                  372.00
# ...
