# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data_csv.csv")

# %%
df
# Out:
#                Actor              Film   Year     Genre  \
# 0     Hrithik Roshan             Dangal  2007     Drama
# 1         Aamir Khan             Barfi!  2018    Action
# 2     Hrithik Roshan             Dangal  2008  Thriller
# 3   Amitabh Bachchan  Bajrangi Bhaijaan  2021    Comedy
# 4        Salman Khan             Kesari  2015  Thriller
# 5         Aamir Khan          Gully Boy  2023   Romance
# 6         Aamir Khan               Piku  2010   Romance
# 7      Rajkummar Rao             Barfi!  2015   Romance
# 8     Shah Rukh Khan              Stree  2000    Biopic
# 9       Akshay Kumar          Gully Boy  2021    Biopic
# 10     Ranbir Kapoor             Dangal  2022    Action
# 11     Ranbir Kapoor               Piku  2010     Drama
#
#     Box Office (INR Crore)  IMDb
# 0                   445.18   8.4
# 1                   255.80   6.4
# 2                   147.77   5.1
# 3                   163.40   5.1
# 4                    65.74   5.8
# ...

# %%
df = df[df['IMDb']>6.0]

# %%
df
# Out:
#              Actor      Film   Year    Genre  Box Office (INR Crore)  IMDb
# 0   Hrithik Roshan     Dangal  2007    Drama                  445.18   8.4
# 1       Aamir Khan     Barfi!  2018   Action                  255.80   6.4
# 5       Aamir Khan  Gully Boy  2023  Romance                  413.47   8.0
# 6       Aamir Khan       Piku  2010  Romance                  311.84   6.2
# 7    Rajkummar Rao     Barfi!  2015  Romance                  229.48   7.5
# 8   Shah Rukh Khan      Stree  2000   Biopic                  176.25   8.2
# 9     Akshay Kumar  Gully Boy  2021   Biopic                   94.01   8.6
# 10   Ranbir Kapoor     Dangal  2022   Action                  405.97   8.3

# %%
# Writing the modified data frame in csv
# index=False will remove the index column in the csv file (which is jumbled up as seen in the above output)
df.to_csv("data_updated.csv", index=False)

# %%
# In similar manner we can read / write in xlsx format
# We can read / write into multiple sheets (multiple sheets in a single workbook)

# %%
# We can read / write data from / to json also
df = pd.read_json("data2.json")

# This will show the output of address in the form of object which is not something we are looking for
# Out:
#    id             name                                   address
# 0   1  Dhwani Vashisth    {'city': 'Delhi', 'ZipCode': '110018'}
# 1   2     Sagar Wadhwa  {'city': 'New York', 'ZipCode': '60601'}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       2 non-null      int64
#  1   name     2 non-null      object
#  2   address  2 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 180.0+ bytes

# %%
data = [
    {
        "id" : 1,
        "name":"Dhwani Vashisth",
        "address":{
            "city" : "Delhi",
            "ZipCode" : "110018"
        }
    },
    {
        "id" : 2,
        "name":"Sagar Wadhwa",
        "address":{
            "city" : "New York",
            "ZipCode" : "60601"
        }
    }
]
# If we want the address not to be displayed as an object, we have to normalize the data
# In this case the sub elements of address will also become a column
df = pd.json_normalize(data)

# %%
df
# Out:
#    id             name address.city address.ZipCode
# 0   1  Dhwani Vashisth        Delhi          110018
# 1   2     Sagar Wadhwa     New York           60601
